# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # For One Company

# %%
url1="https://www.yelu.in/category/restaurants/city:mumbai"
htmlContent=requests.get(url1)
soup=BeautifulSoup(htmlContent.text, 'html.parser')
all_company=soup.find('div',id="listings").find_all(class_=["company with_img g_0","company g_0"])

# Name
print(soup.find('div',id="listings").find('h4').text) 

#company page link
comp_link=(soup.find('div',id="listings").find('h4').find('a').get('href'))
print(("https://www.yelu.in"+comp_link))   

#address
print(soup.find('div',id="listings").find('div',class_="address").text) 

#description
print(soup.find('div',id="listings").find('div',class_="details").text) 

#Tag
print(soup.find('div',id="listings").find('div',class_='cont').find('u',class_='v').text.strip()) 

#Rating
rate=(soup.find('div',id="listings").find('div',class_='rate').text.strip())
print(rate)

#Reviews
rev_link=(soup.find('div',id="listings").find("div",class_='company_reviews').find('a').get('href'))
print(("https://www.yelu.in"+rev_link))
    

#icon
icon=soup.find('div',id="listings").find('div',class_='details').find('span').find('img').get('data-src')
print("https://www.yelu.in/"+icon)
# Out:
# Combo Jumbo
# https://www.yelu.in/company/956077/combo-jumbo
# Shop No. 001, Soho Court, Plot No. 139A, Sindhi Society, Opp. Bhakti Bhavan, Chembur, 400071, Mumbai, Maharashtra
# Combo Jumbo is one of the best restaurants in Chembur, Mumbai. Delicious food on your table, a smile on your face, and peace and contentment in your mind; thatâs what we aim for. Spreading our wings w...
# Verified
# 5.0
# https://www.yelu.in/company/956077/combo-jumbo/reviews
# https://www.yelu.in//img/in/r/_1660221698-94-combo-jumbo-chembur.jpg

# %% [markdown]
# # For One Page

# %%
for info in all_company:
    # Name
    if(info.find('h4')!=None):
        print(info.find('h4').text) 
    else:
        print("No Name")

    #company page link
    comp_link=(info.find('h4').find('a').get('href'))
    print(("https://www.yelu.in"+comp_link))   

    #address
    print(info.find('div',class_="address").text) 

    #description
    if((info.find('div',class_="details"))!=None):
        print(info.find('div',class_="details").text) 
    else:
        print(None)

    #Tag
    if(info.find('u',class_='v')!=None):
        print(info.find('div',class_='cont').find('u',class_='v').text.strip()) 
    else:
        print("Not varified")

    #Rating
    if ((info.find('div',class_="rate"))!=None):
        print((info.find('div',class_="rate").text.strip()))
    else:
        print(('0.0'))
    
    #icon    
    try:
        icon=soup.find('div',id="listings").find('div',class_='details').find('span').find('img').get('data-src')
        Icon.append("https://www.yelu.in/"+icon)
    except:
        print(None)
# Out:
# Combo Jumbo
# https://www.yelu.in/company/956077/combo-jumbo
# Shop No. 001, Soho Court, Plot No. 139A, Sindhi Society, Opp. Bhakti Bhavan, Chembur, 400071, Mumbai, Maharashtra
# Combo Jumbo is one of the best restaurants in Chembur, Mumbai. Delicious food on your table, a smile on your face, and peace and contentment in your mind; thatâs what we aim for. Spreading our wings w...
# Verified
# 5.0
# None
# The Oberoi, Mumbai
# https://www.yelu.in/company/926961/the-oberoi-mumbai
# The Oberoi, Nariman Point, Mumbai - 400 021, Mumbai, Maharashtra
# The Oberoi, Mumbai enjoys an unrivalled position on the exclusive Marine Drive, with unparalleled views of the ocean, and the Queenâs Necklace â a golden crescent of lights that adorns the shoreline a...
# Verified
# 0.0
# None
# The Byke Suraj Plaza,Thane
# https://www.yelu.in/company/937860/the-byke-suraj-plazathane
# Saibaba Vihar Complex, Anand Nagar, Ghodbunder Road, Thane (West) 400 615, Mumbai, Maharashtra
# The Byke Suraj Plaza, Luxury Hotel in Thane has 122 luxuriously spacious rooms which offer coziness & comfort of a Home, a guest would wish for. All our rooms are exquisite, stylishly designed, perfec...
# Verified
# 0.0
# None
# Delhi-Darbar
# https://www.yelu.in/company/918395/delhi-darbar
# Mansuri Caterers SBS Road, Near Regal Cinema, Colaba, Mumbai, Maharashtra
# Delhi Darbar is famous restaurants in Mumbai providing quick services, The ambiance is good, The portions are HUGE and the prices are moderate with delicious Indian & Mughlai dishes like Biryani, Mutt...
# Verified
# 0.0
# None
# Queensline SeaYAH
# https://www.yelu.in/company/950312/queensline-seayah
# 606, Raheja Chambers, Free Press Journal Road, Nariman Point, Mumbai, Maharashtra
# Queensline SeaYAH & Neverland are luxury floatel / floating restaurant located at Gateway of India, Mumbai. It is one of its kind floatel / floating restaurantÂ which serves exotic global cuisine with ...
# Verified
# 0.0
# None
# Thyme Bistro- Cafe, Pub and Restaurant
# https://www.yelu.in/company/936198/thyme-bistro-cafe-pub-and-restaurant
# 1st Floor, Huma Mall, L B S Marg, Kanjurmarg West, Bhandup West, Mumbai, Maharashtra 400078, Mumbai, Maharashtra
# Thyme- Cafe, Bar, Restaurant located at Huma Mall which is just 10 mins from Powai. Thyme Bistro is a progressive cafe for office goers to throw away their masks of sanity, break all the rules and jus...
# Verified
# 0.0
# None
# Greenesta Global
# https://www.yelu.in/company/947211/greenesta-global
# WeWork, Embassy 247, L.B.S Road, Vikhroli (West), Mumbai, Maharashtra
# Greenesta Global is a marketplace for vegan products, services and solutions.Welcome to the world of Greenesta Global, a compassionate yet scientific e-commerce marketplace for vegan products and solu...
# Verified
# 0.0
# None
# London Taxi
# https://www.yelu.in/company/945003/london-taxi
# A Wing, Ground Floor, Trade Centre, Kamala Mills Lower, Parel, Mumbai, Maharashtra 400013, Mumbai, Maharashtra
# London Taxi is one of the best restaurants in Lower Parel, South Mumbai. Based on the theme of London city, this classy resto-bar at Kamala Mills serves menu from across the globe with modern interpre...
# Verified
# 0.0
# None
# The Forest Club Resort
# https://www.yelu.in/company/953032/the-forest-club-resort
# Karjat - Neral Rd, near Namak Restaurant, Kotwal Nagar, Kirawali, Karjat, Mumbai, Maharashtra
# A Luxurious resort near Karjat - Mumbai for a perfect romantic weekend getaway or one day picnic with your partner, family of friends. 5 star ammenities like swimming pool, infinity pool, parks and mo...
# Verified
# 0.0
# None
# Golden Prize
# https://www.yelu.in/company/951103/golden-prize
# SB-15, 2F, Highland,Corporate Centre,Kapurbawdi, Majiwada,Thane (W) 400607, Mumbai, Maharashtra
# Golden Prize India is a part of Ashokasha Group of Companies and was formed with the focus of bringing the best and most innovative foods to Indian consumers from around the world. Golden Prize is a l...
# Verified
# 0.0
# None
# HCA India
# https://www.yelu.in/company/946847/hca-india
# 1201, Building 2D, Dreams CHS, LBS Marg, Bhandup West, Mumbai - 400078, Mumbai, Maharashtra
# HCA is a restaurant consultant in Delhi and Mumbai. HCA is a leading F&B consultancy, providing specialized F&B services from Conceptualisation & Ideation to Budgeting And P&L, Interior design, Kitche...
# Verified
# 0.0
# None
# Seafood From Norway
# https://www.yelu.in/company/944023/seafood-from-norway
# TCG Financial Centre, 3rd Floor, C-53, G Block,, Bandra Kurla Complex, Bandra (E), Mumbai, Maharashtra
# Seafood from Norway presents to you the original Norwegian Seafood that comes from our cold and clear waters with perfect environment and optimum temperature to nurture the worldâs most popular seafoo...
# Verified
# 0.0
# None
# Chiranjiv Steel Centre.
# https://www.yelu.in/company/935778/chiranjiv-steel-centre
# 52/54, C.P. Tank Road, 2nd Floor, Room No. 15, Mumbai, Maharashtra
# We are among the leading manufacturers and exporters of Butt Weld / Forged Pipe Fittings & Flanges. Apart from these, we are also counted as a prominent stockiest & Importer of Pipes, Tubes, Sheets, P...
# Verified
# 0.0
# None
# A1 Hotel
# https://www.yelu.in/company/306140/a1-hotel
# Pragati Shopping Centre, 3 Flr, Malad (E), Maharastra, Mumbai
# None
# Not varified
# 0.0
# None
# Alpha Marine
# https://www.yelu.in/company/556605/alpha-marine
# Sunrise Society,Grn Flr. Flat 3 , 19 th, Mumbai, Maharashtra
# Manufacturer Exporters Of sea food, lobsters, prawns, pomfret, seerfish, tuna, mackerel, mudcrab
# Not varified
# 0.0
# None
# Al Taha Exports
# https://www.yelu.in/company/555468/al-taha-exports
# Godwon No 51 Dharavi 16, Mumbai, Maharashtra
# Manufacturer Exporters / Importers Of meat products, chicken, fishes
# Not varified
# 0.0
# None
# Ambrosia Fruits & Veg. Private Limited
# https://www.yelu.in/company/555445/ambrosia-fruitsveg-private-limited
# 6, Abdul Sattar, Fitwala Road, Nr. Elphinstone Stn. (W),, Mumbai, Maharashtra
# Manufacturer Exporters Of Fruits, Vegetables, Onion, Fish, Mutton
# Not varified
# 0.0
# None
# Aquarium Paradise
# https://www.yelu.in/company/506530/aquarium-paradise
# B26, Abhishek, B-6, Ratan Nagar, Borivili East, Mumbai, Maharashtra
# Manufacturers / Wholesale Suppliers Of aquariums, customized freshwater aquarium setups, customised marine aquarium setups, Marine Aquariums, Aquarium Accessories, Fish Tanks, Fresh Water Fish, Salt W...
# Not varified
# 0.0
# None
# Aquatic World
# https://www.yelu.in/company/556599/aquatic-world
# Rahat Bazar Manzil, 1st Floor, 1-d, Fort Road, Mahim, Mumbai, Maharashtra
# Exporters / Importers Of ornamental fish, aquatic products
# Not varified
# 0.0
# None
# Aruna Refreshments
# https://www.yelu.in/company/301951/aruna-refreshments
# Bombay Talkies Compound, Malad (W), Maharastra, Mumbai
# None
# Not varified
# 0.0
# None
# Ashvina Trading Co.
# https://www.yelu.in/company/505830/ashvina-trading-co
# Shop No. 9, Hastagiri, Ashok Chakravarti, Mumbai, Maharashtra
# Manufacturer Exporters Of Agricultural Food Products, Fresh Vegetables, Fruits, Foodstuffs, Fish, Newspaper, Magazine
# Not varified
# 0.0
# None
# Bhushan Foods
# https://www.yelu.in/company/556547/bhushan-foods
# Wadala Road, Mumbai, Maharashtra
# Manufacturer Exporters Of sea food
# Not varified
# 0.0
# None
# Cake N Candy
# https://www.yelu.in/company/305877/cake-n-candy
# 126, Andheri Industrial Estate, Off Veera Desai Road, Andheri (W), Maharastra, Mumbai
# None
# Not varified
# 0.0
# None
# Forstar Instafoods
# https://www.yelu.in/company/554837/forstar-instafoods
# M-52, Midc Industrial Area, Taloja,, Mumbai, Maharashtra
# Exporters / Manufacturers Of sea foods, rice meals, soup, pickles, frozen seafood, shrimp, soups, frozen seafood products
# Not varified
# 0.0
# None
# Forstar Frozen Foods Pvt. Ltd.
# https://www.yelu.in/company/556650/forstar-frozen-foods-pvt-ltd
# 505 A, Galleria, Hiranandani Gardens, Mumbai, Maharashtra
# Exporters Of shrimps, frozen shrimps, fish, marine product
# Not varified
# 0.0
# None
# Garden Court Restaurant
# https://www.yelu.in/company/441316/garden-court-restaurant
# Junction of J. P. Road Veera Desai Road Andheri (W), Mumbai, Maharashtra
# None
# Not varified
# 0.0
# None
# Goa Portuguesa
# https://www.yelu.in/company/56380/goa-portuguesa
# Mili Bldg, Opp. Mahim HPO, Kataria Road, Mahim, Mumbai, Maharashtra
# None
# Not varified
# 0.0
# None
# Hardcastle Restaurant Pvt Ltd
# https://www.yelu.in/company/326064/hardcastle-restaurant-pvt-ltd
# Ashiana 69-C, Bhulabhai Desai Road, Maharastra, Mumbai
# None
# Not varified
# 0.0
# None
# Hotel Samrat
# https://www.yelu.in/company/441315/hotel-samrat
# 3rd Road, Near Khar Railway Staion, Khar (West), Mumbai, Maharashtra
# None
# Not varified
# 0.0
# None
# H. P. Enterprise
# https://www.yelu.in/company/556647/h-p-enterprise
# Sewri Cross Road,Sewri (w), Mumbai, Maharashtra
# Exporters Of dried fishmaws, dried sharkfins, marine foods
# Not varified
# 0.0
# None

# %% [markdown]
# # Whole Website

# %%
dataframe_final = pd.DataFrame()
for page in range(1,38):  
     
    response=requests.get("https://www.yelu.in/category/restaurants/{}/city:mumbai".format(page))
    soup=BeautifulSoup(response.text,'html.parser')
    all_company=soup.find('div',id="listings").find_all(class_=["company with_img g_0","company g_0"])

    
    Comapny_Name = []  
    Address = []                                       
    Description =[]
    Rating =[]
    Varified_Tag = []
    Icon=[]
    Company_Page_link =[]

    for info in all_company:
               # Name
        if(info.find('h4')!=None):
            Comapny_Name.append(info.find('h4').text) 
        else:
            Comapny_Name.append("No Name")

        #company page link
        comp_link=(info.find('h4').find('a').get('href'))
        Company_Page_link.append(("https://www.yelu.in"+comp_link))   

        #address
        Address.append(info.find('div',class_="address").text) 

        #description
        if((info.find('div',class_="details"))!=None):
            Description.append(info.find('div',class_="details").text) 
        else:
            Description.append(None)

        #Tag
        if(info.find('u',class_='v')!=None):
            Varified_Tag.append(info.find('div',class_='cont').find('u',class_='v').text.strip()) 
        else:
            Varified_Tag.append("Not varified")

        #Rating
        if ((info.find('div',class_="rate"))!=None):
            Rating.append((info.find('div',class_="rate").text.strip()))
        else:
            Rating.append(('0.0'))
            
        #Icon
        try:
            icon=soup.find('div',id="listings").find('div',class_='details').find('span').find('img').get('data-src')
            Icon.append("https://www.yelu.in/"+icon)
        except:
            Icon.append(None)
    
        
    data={
        "Company_Name":Comapny_Name,
        "Company_Address":Address,
        "Descriptin": Description,
        "Varification":Varified_Tag,
        "Rating":Rating,
        "Company_Icon":Icon,
        "Company_Page":Company_Page_link
    }
    df=pd.DataFrame(data)
    dataframe_final = dataframe_final.append(df, ignore_index=True)
# Out:
# C:\Users\star\AppData\Local\Temp\ipykernel_8000\685934880.py:67: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe_final = dataframe_final.append(df, ignore_index=True)

# %%
dataframe_final.to_json("Mumbai_Restaurants.json")

# %%
pd.read_json("Mumbai_Restaurants.json")
# Out:
#                     Company_Name  \
# 0                    Combo Jumbo
# 1             The Oberoi, Mumbai
# 2     The Byke Suraj Plaza,Thane
# 3                   Delhi-Darbar
# 4              Queensline SeaYAH
# ...                          ...
# 1103                  Cuppa Cafe
# 1104   Patil Gally Mahila Mandal
# 1105              Steaming Momos
# 1106              Too Many Cooks
# 1107  Varsova Koliwada Sea Foods
#
#                                         Company_Address  \
# 0     Shop No. 001, Soho Court, Plot No. 139A, Sindh...
# 1     The Oberoi, Nariman Point, Mumbai - 400 021, M...
# 2     Saibaba Vihar Complex, Anand Nagar, Ghodbunder...
# 3     Mansuri Caterers SBS Road, Near Regal Cinema, ...
# 4     606, Raheja Chambers, Free Press Journal Road,...
# ...                                                 ...
# 1103  Cinemax, Infinity Mall, Link Road, Lokhandwala...
# 1104  Ganesh Temple Ground, Near Church, Yari Road, ...
# 1105  Shop No.6, Gold Crown Housing Society, J P Roa...
# 1106  1002, Midtown Appartments, B G Kher Marg, Worl...
# 1107   Patil Gally No.2, Bander, Andheri (West), Mumbai
#
#                                              Descriptin  Varification  Rating  \
# 0     Combo Jumbo is one of the best restaurants in ...      Verified       5
# 1     The Oberoi, Mumbai enjoys an unrivalled positi...      Verified       0
# 2     The Byke Suraj Plaza, Luxury Hotel in Thane ha...      Verified       0
# 3     Delhi Darbar is famous restaurants in Mumbai p...      Verified       0
# 4     Queensline SeaYAH & Neverland are luxury float...      Verified       0
# ...                                                 ...           ...     ...
# 1103                                               None  Not varified       0
# 1104                                               None  Not varified       0
# 1105                                               None  Not varified       0
# 1106                                               None  Not varified       0
# 1107                                               None  Not varified       0
#
#                                            Company_Icon  \
# 0     https://www.yelu.in//img/in/r/_1660221698-94-c...
# 1     https://www.yelu.in//img/in/r/_1660221698-94-c...
# 2     https://www.yelu.in//img/in/r/_1660221698-94-c...
# 3     https://www.yelu.in//img/in/r/_1660221698-94-c...
# 4     https://www.yelu.in//img/in/r/_1660221698-94-c...
# ...                                                 ...
# 1103                                               None
# 1104                                               None
# 1105                                               None
# 1106                                               None
# 1107                                               None
#
#                                            Company_Page
# 0        https://www.yelu.in/company/956077/combo-jumbo
# 1     https://www.yelu.in/company/926961/the-oberoi-...
# 2     https://www.yelu.in/company/937860/the-byke-su...
# 3       https://www.yelu.in/company/918395/delhi-darbar
# 4     https://www.yelu.in/company/950312/queensline-...
# ...                                                 ...
# 1103      https://www.yelu.in/company/889406/cuppa-cafe
# 1104  https://www.yelu.in/company/888278/patil-gally...
# 1105  https://www.yelu.in/company/891446/steaming-momos
# 1106  https://www.yelu.in/company/888306/too-many-cooks
# 1107  https://www.yelu.in/company/888317/varsova-kol...
#
# [1108 rows x 7 columns]
