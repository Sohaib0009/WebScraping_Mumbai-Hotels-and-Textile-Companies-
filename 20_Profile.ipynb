# %%
import pandas as pd

# %%
Rest=pd.read_json("Mumbai_Restaurants.json")

# %%
Rest.head()
# Out:
#                  Company_Name  \
# 0                 Combo Jumbo
# 1          The Oberoi, Mumbai
# 2  The Byke Suraj Plaza,Thane
# 3                Delhi-Darbar
# 4           Queensline SeaYAH
#
#                                      Company_Address  \
# 0  Shop No. 001, Soho Court, Plot No. 139A, Sindh...
# 1  The Oberoi, Nariman Point, Mumbai - 400 021, M...
# 2  Saibaba Vihar Complex, Anand Nagar, Ghodbunder...
# 3  Mansuri Caterers SBS Road, Near Regal Cinema, ...
# 4  606, Raheja Chambers, Free Press Journal Road,...
#
#                                           Descriptin Varification  Rating  \
# 0  Combo Jumbo is one of the best restaurants in ...     Verified       5
# 1  The Oberoi, Mumbai enjoys an unrivalled positi...     Verified       0
# 2  The Byke Suraj Plaza, Luxury Hotel in Thane ha...     Verified       0
# 3  Delhi Darbar is famous restaurants in Mumbai p...     Verified       0
# 4  Queensline SeaYAH & Neverland are luxury float...     Verified       0
#
# ...

# %%
Rest.isna().sum()
# Out:
# Company_Name         0
# Company_Address      0
# Descriptin         203
# Varification         0
# Rating               0
# Company_Icon       210
# Company_Page         0
# dtype: int64

# %%
Profile=Rest.dropna().head(20)

# %%
Profile
# Out:
#                               Company_Name  \
# 0                              Combo Jumbo
# 1                       The Oberoi, Mumbai
# 2               The Byke Suraj Plaza,Thane
# 3                             Delhi-Darbar
# 4                        Queensline SeaYAH
# 5   Thyme Bistro- Cafe, Pub and Restaurant
# 6                         Greenesta Global
# 7                              London Taxi
# 8                   The Forest Club Resort
# 9                             Golden Prize
# 10                               HCA India
# 11                     Seafood From Norway
# 12                Chiranjiv Steel Centre.
# 14                            Alpha Marine
# 15                         Al Taha Exports
# 16  Ambrosia Fruits & Veg. Private Limited
# 17                       Aquarium Paradise
# 18                           Aquatic World
# 20                     Ashvina Trading Co.
# 21                           Bhushan Foods
#
# ...

# %%
Profile.to_json("Profile_20_Company.json",indent=6)

# %%
pd.read_json("Profile_20_Company.json")
# Out:
#                               Company_Name  \
# 0                              Combo Jumbo
# 1                       The Oberoi, Mumbai
# 2               The Byke Suraj Plaza,Thane
# 3                             Delhi-Darbar
# 4                        Queensline SeaYAH
# 5   Thyme Bistro- Cafe, Pub and Restaurant
# 6                         Greenesta Global
# 7                              London Taxi
# 8                   The Forest Club Resort
# 9                             Golden Prize
# 10                               HCA India
# 11                     Seafood From Norway
# 12                Chiranjiv Steel Centre.
# 14                            Alpha Marine
# 15                         Al Taha Exports
# 16  Ambrosia Fruits & Veg. Private Limited
# 17                       Aquarium Paradise
# 18                           Aquatic World
# 20                     Ashvina Trading Co.
# 21                           Bhushan Foods
#
# ...
